# %% [markdown]
# <a href="https://colab.research.google.com/github/Judith-solomi/AI-and-ML-Assignments/blob/main/operaters%20and%20datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data type
#
# 1.numeric
#
# 2.sequence

# %%
#numeric datatype --> integer (int class), float (float class), complex (complex class)
a=5
b=5.2

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
c= 2+3j
print(type(c))
# Out:
# <class 'complex'>

# %%
#sequence datatype --> string (str class), list (list class), tuple (tuple class)
d= "welcome"
print(type(d))
print(d)
# Out:
# <class 'str'>
# welcome

# %%
e= [1,2,3, "hello"]
print(e)
print(type(e))
print(e[3])
# Out:
# [1, 2, 3, 'hello']
# <class 'list'>
# hello

# %%
f=(1,2,3, "hello")
print(f)
print(type(f))
# Out:
# (1, 2, 3, 'hello')
# <class 'tuple'>

# %% [markdown]
# Operators
#
# Arithmetic Operators
#
# Comparison (Relational) Operators
#
# Assignment Operators
#
# Logical Operators
#
# Bitwise Operators
#
# Membership Operators
#
# Identity Operators

# %%
#Arithmetic Operators
a = 15
b = 4

print("Addition:", a + b)

print("Subtraction:", a - b)

print("Multiplication:", a * b)

print("Division:", a / b)

print("Floor Division:", a // b)

print("Modulus:", a % b)

print("Exponentiation:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %%
#Comparison Operators
a = 13
b = 33

print(a > b)
print(a < b)
print(a == b)
print(a != b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#Logical Operators
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# Bitwise Operators in Python are as follows:
#
# Bitwise NOT
#
# Bitwise Shift
#
# Bitwise AND
#
# Bitwise XOR
#
# Bitwise OR

# %%
a = 10
b = 4

print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %%
#Assignment Operators
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %%
#Identity Operators
a = 10
b = 20
c = a

print(a is not b)
print(a is c)
# Out:
# True
# True

# %%
#Membership Operators
x = 24
y = 20
my_list = [10, 20, 30, 40, 50]

if (x not in my_list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")

if (y in my_list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %%
#Ternary Operator
a, b = 10, 20
min = a if a < b else b

print(min)
# Out:
# 10

# %% [markdown]
# **List methods**

# %%
#append()
a = [1, 2, 3]

# Add 4 to the end of the list
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
#copy()
a = [1, 2, 3]

# Create a copy of the list
b = a.copy()
print(b)
# Out:
# [1, 2, 3]

# %%
#clear()
a = [1, 2, 3]

# Remove all elements from the list
a.clear()
print(a)
# Out:
# []

# %%
#count()
a = [1, 2, 3, 2]

# Count occurrences of 2 in the list
print(a.count(2))
# Out:
# 2

# %%
#extend()
a = [1, 2]

# Extend list a by adding elements from list [3, 4]
a.extend([3, 4])
print(a)
# Out:
# [1, 2, 3, 4]

# %%
#index()
a = [1, 2, 3]

# Find the index of 2 in the list
print(a.index(2))
# Out:
# 1

# %%
#insert()
a = [1, 3]

# Insert 2 at index 1
a.insert(1, 2)
print(a)
# Out:
# [1, 2, 3]

# %%
#pop()
a = [1, 2, 3]

# Remove and return the last element in the list
a.pop()
print(a)
# Out:
# [1, 2]

# %%
#remove()
a = [1, 2, 3]

# Remove the first occurrence of 2
a.remove(2)
print(a)
# Out:
# [1, 3]

# %%
#reverse()
a = [1, 2, 3]

# Reverse the list order
a.reverse()
print(a)
# Out:
# [3, 2, 1]

# %%
#sort()
a = [3, 1, 2]

# Sort the list in ascending order
a.sort()
print(a)
# Out:
# [1, 2, 3]

# %%
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_899/1497285116.py in <cell line: 0>()
#       1 del a
# ----> 2 print(a)
#
# NameError: name 'a' is not defined

# %%
print(3==3.0)
# Out:
# True

# %%
age = int(input("Enter student age: "))

if age > 20:
    print("You are able to get AI role")
elif age < 15:
    print("You are also not eligible")
elif age >= 18:
    print("You are just +18")
elif age == 19:
    print("you can get trainer role")
elif age < 20:
    print("You are not eligible")
# Out:
# Enter student age: 10
# You are also not eligible
